# %%
import py_entitymatching as em
import pandas as pd

# %%
source1 = 'source1_cleaned.csv'
source2 = 'source2_cleaned.csv'

# Read the data
data_source1 = em.read_csv_metadata(source1)
data_source2 = em.read_csv_metadata(source2)

# Set the metadata
em.set_key(data_source1, 'ID')
em.set_key(data_source2, 'ID')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# True

# %%
# Overlap blocker
ob = em.OverlapBlocker()

C1 = ob.block_tables(data_source1, data_source2, 'Name', 'Name', word_level=True, overlap_size=3, 
                    l_output_attrs=['Name', 'Author', 'Publisher'], 
                    r_output_attrs=['Name', 'Author', 'Publisher'],
                    show_progress=False)

# %%
len(C1)
# Out:
# 118876

# %%
# Attribute equivalence blocker
ab = em.AttrEquivalenceBlocker()
C2 = ab.block_candset(C1, l_block_attr='Author', r_block_attr='Author')
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01

# %%
len(C2)
# Out:
# 333

# %%
C2
# Out:
#            _id  ltable_ID  rtable_ID  \
# 1115      1115       1281         22
# 1279      1279         31         26
# 3231      3231        620         94
# 3370      3370        529         97
# 3701      3701       1165        104
# 4427      4427        337        119
# 4631      4631       2798        119
# 8637      8637        527        212
# 8643      8643        796        212
# 8775      8775        611        217
# 8803      8803        611        218
# 9651      9651        631        257
# 10637    10637        809        272
# 10642    10642       1900        272
# 10643    10643       1941        272
# 11059    11059        136        281
# 11459    11459         60        285
# 11469    11469        401        285
# 11472    11472        478        285
# 12031    12031        657        318
# 12957    12957        262        357
# 13683    13683        852        359
# 13720    13720        611        360
# 14678    14678        631        369
# ...

# %%
# Rule based blocking
block_f = em.get_features_for_blocking(data_source1, data_source2, validate_inferred_attr_types=False)

# %%
block_f
# Out:
#                                        feature_name   left_attribute  \
# 0                                         ID_ID_exm               ID
# 1                                         ID_ID_anm               ID
# 2                                    ID_ID_lev_dist               ID
# 3                                     ID_ID_lev_sim               ID
# 4                         Name_Name_jac_qgm_3_qgm_3             Name
# 5                     Name_Name_cos_dlm_dc0_dlm_dc0             Name
# 6                                     Name_Name_mel             Name
# 7                                Name_Name_lev_dist             Name
# 8                                 Name_Name_lev_sim             Name
# 9                     Author_Author_jac_qgm_3_qgm_3           Author
# 10                Author_Author_cos_dlm_dc0_dlm_dc0           Author
# 11                Author_Author_jac_dlm_dc0_dlm_dc0           Author
# 12                                Author_Author_mel           Author
# ...
